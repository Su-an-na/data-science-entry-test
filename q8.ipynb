# %%
prompt_a = """
I am a marketing manager at a retail company and we have just finished 
a three-month campaign. My team has collected customer feedback through 
an online survey and we now have about 500 responses stored in a 
spreadsheet. Each response includes the customer's age group, the 
product they purchased, their satisfaction rating from 1 to 5, and a 
short written comment. I need to present the findings to our CEO next 
Friday in a way that is easy to understand. Can you analyse this data 
for me, highlight which age groups and products have the lowest 
satisfaction scores, identify the most common complaints from the 
written comments, and summarise everything in a short paragraph I can 
use as an executive summary?
"""

prompt_b = """
Role: You are a data analyst helping a retail marketing team.
Task: Analyse customer survey data from a 3-month campaign.
Data: 500 responses containing age group, product purchased, 
satisfaction rating (1-5), and written comments.
Steps:
1. Identify age groups and products with the lowest satisfaction scores.
2. Extract the most common themes from the written comments.
3. Summarise findings in an executive summary paragraph.
Audience: CEO presentation on Friday.
Constraints: Keep the summary concise and free of technical jargon.
"""


# Task 1
# Read both prompts above carefully, then answer the questions below as comments.

# Q8a: Which prompt do you think will get a better response from an AI?
# Your answer: prompt b

# Q8b: Give TWO reasons to support your choice.
# Your answer (Reason 1): Each key elements of the output is clearly stated such  Role, Task, Data, Steps, Audience and Constraint. This allow
# the AI to understand the context for each sentence and steps what it expects the AI to do. The output follow  
# these key elements so that it is easy to extract the output.

# Your answer (Reason 2): It is telling the AI to act as a data analyst with the clear role, task, steps it expects a typical data analyst to do.
# this allow the AI to act as a proper data analyst following a typical data analyst framework. Unlike prompt a, its just tell the prompt to
# analyse by certain data points and so on where therefore the AI may not follow a typical data analyst framework method in its output.

# Q8c: What is ONE strength of the prompt you did NOT choose?
# Your answer: Prompt a is "more specific" with its data and comments compare to prompt b. Prompt a clearly mention the data is in spreadsheet
# Mentioning data source can help the AI with less ambiquity when deciding to construct the output. 
# Prompt a also asked specifically for complaints from comments. This allow for more actionable insights that impacts thier customer rather than just 
# looking for themes only.




# Task 2
# Rewrite either prompt by borrowing ONE element from the other
# to make it stronger. Explain what you borrowed and why.
# Your answer: I will borrow "be more specific" on the data source and complaints. 
# I will include the spreadsheet file name and explaining the variables/columns names. 
# This will allow the AI to use the relevant information to analyse instead of it may use the wrong variable.
# I will also add another steps to identify the complaints from the wriiten comments for actionable insights.
""" Re-written prompt:
Role: You are a data analyst helping a retail marketing team.
Task: Analyse customer survey data from a 3-month campaign.
Data: Attached spreadsheet.xlsx file contain 500 responses containing age group(column variable: age_group)
, product purchased(column variable: product_purchased), 
satisfaction rating (values range of 1 to 5)(column variable: satisfaction_rate, where 1 is not satisfied and 5 is most satisfied)
, and written comments(column variable: Comments).
Steps:
1. Identify age groups and products with the lowest satisfaction scores.
2. Extract the most common themes from the written comments. 
3. Identify the most common complaints from the written comments.
4. Summarise findings in an executive summary paragraph.
Audience: CEO presentation on Friday.
Constraints: Keep the summary concise and free of technical jargon.
"""
